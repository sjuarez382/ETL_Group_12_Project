# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
tv_shows_file = "Resources/tv_shows.csv"
tv_shows_df = pd.read_csv(tv_shows_file)
tv_shows_df.head()
# Out:
#    Unnamed: 0             Title  Year  Age  IMDb Rotten Tomatoes  Netflix  \
# 0           0      Breaking Bad  2008  18+   9.5             96%        1
# 1           1   Stranger Things  2016  16+   8.8             93%        1
# 2           2       Money Heist  2017  18+   8.4             91%        1
# 3           3          Sherlock  2010  16+   9.1             78%        1
# 4           4  Better Call Saul  2015  18+   8.7             97%        1
#
#    Hulu  Prime Video  Disney+  type Unnamed: 11
# 0     0            0        0     1         NaN
# 1     0            0        0     1         NaN
# 2     0            0        0     1         NaN
# 3     0            0        0     1         NaN
# 4     0            0        0     1         NaN

# %%
netflix_shows_df = tv_shows_df[['Title', 'Age', 'Netflix']]
netflix_shows_df.head()
# Out:
#               Title  Age  Netflix
# 0      Breaking Bad  18+        1
# 1   Stranger Things  16+        1
# 2       Money Heist  18+        1
# 3          Sherlock  16+        1
# 4  Better Call Saul  18+        1

# %%
netflix_shows_df.rename(columns={'Netflix':'streaming_service'})
# Out:
#                                 Title  Age  streaming_service
# 0                        Breaking Bad  18+                  1
# 1                     Stranger Things  16+                  1
# 2                         Money Heist  18+                  1
# 3                            Sherlock  16+                  1
# 4                    Better Call Saul  18+                  1
# ...                               ...  ...                ...
# 5606  Tut's Treasures: Hidden Secrets  NaN                  0
# 5607                 Paradise Islands  NaN                  0
# 5608                      Wild Russia  NaN                  0
# 5609                      Love & Vets  NaN                  0
# 5610         United States of Animals  NaN                  0
#
# [5611 rows x 3 columns]

# %%
netflix_shows_df = netflix_shows_df.rename(columns={'Netflix':'streaming_service', "Title":'title', 'Age':'age'})

netflix_shows_df.loc[netflix_shows_df.streaming_service == 1, 'streaming_service']= 'Netflix'

# %%
netflix_shows_df
# Out:
#                                 title  age streaming_service
# 0                        Breaking Bad  18+           Netflix
# 1                     Stranger Things  16+           Netflix
# 2                         Money Heist  18+           Netflix
# 3                            Sherlock  16+           Netflix
# 4                    Better Call Saul  18+           Netflix
# ...                               ...  ...               ...
# 5606  Tut's Treasures: Hidden Secrets  NaN                 0
# 5607                 Paradise Islands  NaN                 0
# 5608                      Wild Russia  NaN                 0
# 5609                      Love & Vets  NaN                 0
# 5610         United States of Animals  NaN                 0
#
# [5611 rows x 3 columns]

# %%
prime_tv_shows_file = "Resources/Prime TV Shows Data set.csv"
prime_tv_shows_df = pd.read_csv(prime_tv_shows_file, encoding='unicode_escape')
prime_tv_shows_df.head()
# Out:
#    S.no.           Name of the show  Year of release  No of seasons available  \
# 0      1                 Pataal Lok           2020.0                      1.0
# 1      2                     Upload           2020.0                      1.0
# 2      3  The Marvelous Mrs. Maisel           2017.0                      3.0
# 3      4     Four More Shots Please           2019.0                      2.0
# 4      5                    Fleabag           2016.0                      2.0
#
#   Language          Genre  IMDb rating Age of viewers
# 0    Hindi          Drama          7.5            18+
# 1  English  Sci-fi comedy          8.1            16+
# 2  English  Drama, Comedy          8.7            16+
# 3    Hindi  Drama, Comedy          5.3            18+
# 4  English         Comedy          8.7            18+

# %%
prime_tv_shows_df['Streaming_Service']= 'Amazon_Prime_Video'
prime_tv_shows_df.head()
# Out:
#    S.no.           Name of the show  Year of release  No of seasons available  \
# 0      1                 Pataal Lok           2020.0                      1.0
# 1      2                     Upload           2020.0                      1.0
# 2      3  The Marvelous Mrs. Maisel           2017.0                      3.0
# 3      4     Four More Shots Please           2019.0                      2.0
# 4      5                    Fleabag           2016.0                      2.0
#
#   Language          Genre  IMDb rating Age of viewers   Streaming_Service
# 0    Hindi          Drama          7.5            18+  Amazon_Prime_Video
# 1  English  Sci-fi comedy          8.1            16+  Amazon_Prime_Video
# 2  English  Drama, Comedy          8.7            16+  Amazon_Prime_Video
# 3    Hindi  Drama, Comedy          5.3            18+  Amazon_Prime_Video
# 4  English         Comedy          8.7            18+  Amazon_Prime_Video

# %%
prime_tv_shows_df['Streaming_Service'] = 'Amazon_Prime_Video'
prime_tv_shows_df.head()
# Out:
#    S.no.           Name of the show  Year of release  No of seasons available  \
# 0      1                 Pataal Lok           2020.0                      1.0
# 1      2                     Upload           2020.0                      1.0
# 2      3  The Marvelous Mrs. Maisel           2017.0                      3.0
# 3      4     Four More Shots Please           2019.0                      2.0
# 4      5                    Fleabag           2016.0                      2.0
#
#   Language          Genre  IMDb rating Age of viewers   Streaming_Service
# 0    Hindi          Drama          7.5            18+  Amazon_Prime_Video
# 1  English  Sci-fi comedy          8.1            16+  Amazon_Prime_Video
# 2  English  Drama, Comedy          8.7            16+  Amazon_Prime_Video
# 3    Hindi  Drama, Comedy          5.3            18+  Amazon_Prime_Video
# 4  English         Comedy          8.7            18+  Amazon_Prime_Video

# %%
prime_tv_shows_df = prime_tv_shows_df.rename(columns={'Name of the show':'Title'})
prime_tv_shows_df = prime_tv_shows_df.rename(columns={'Age of viewers':'Age'})

# %%
connection_string = "postgress:1234@localhost:5432/streaming_service"
engine = create_engine(f'postgresql://{connection_string}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-3821037b3243> in <module>
#       1 connection_string = "postgress:1234@localhost:5432/streaming_service"
# ----> 2 engine = create_engine(f'postgresql://{connection_string}')
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\__init__.py in create_engine(*args, **kwargs)
#     498     strategy = kwargs.pop("strategy", default_strategy)
#     499     strategy = strategies.strategies[strategy]
# --> 500     return strategy.create(*args, **kwargs)
#     501
#     502
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ---> 87             dbapi = dialect_cls.dbapi(**dbapi_args)
#      88
#      89         dialect_args["dbapi"] = dbapi
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in dbapi(cls)
#     751     @classmethod
#     752     def dbapi(cls):
# --> 753         import psycopg2
#     754
#     755         return psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
engine.table_names()

# %%
netflix_shows_df = netflix_shows_df.drop_duplicates(subset='title')

# %%
netflix_shows_df.to_sql(name='netflix', con=engine, if_exists='append', index=False)
